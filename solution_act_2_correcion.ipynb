# %% [markdown]
# Solución Actividad 2
#
# * Daniela Nath - 10192004
# * Daniel Sofia Peñuela - 10192007

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly

# %%
act_2 = pd.read_csv('/content/activity_2_ml.csv')

# %%
act_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 353 entries, 0 to 352
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   YEAR                 353 non-null    int64
#  1   AGE                  353 non-null    int64
#  2   DISTANCE_BUS         353 non-null    float64
#  3   DISTANCE_INTERSTATE  353 non-null    float64
#  4   PRICE                283 non-null    float64
#  5   ROOMS                353 non-null    int64
#  6   AREA                 353 non-null    int64
#  7   LAND                 353 non-null    float64
#  8   BATHS                353 non-null    int64
# dtypes: float64(4), int64(5)
# memory usage: 24.9 KB

# %% [markdown]
# verificacion de variables
# # year

# %%
y = 'YEAR'

# %%
def fix_year(YEAR):
    if YEAR < 100:
      return YEAR + 1900
    return YEAR

act_2['YEAR'] = act_2['YEAR'].apply(fix_year)

# %%
act_2['YEAR'].unique()
# Out:
# array([1978, 1981])

# %%
act_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 353 entries, 0 to 352
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   YEAR                 353 non-null    int64
#  1   AGE                  353 non-null    int64
#  2   DISTANCE_BUS         353 non-null    float64
#  3   DISTANCE_INTERSTATE  353 non-null    float64
#  4   PRICE                283 non-null    float64
#  5   ROOMS                353 non-null    int64
#  6   AREA                 353 non-null    int64
#  7   LAND                 353 non-null    float64
#  8   BATHS                353 non-null    int64
# dtypes: float64(4), int64(5)
# memory usage: 24.9 KB

# %% [markdown]
# eliminar duplicados

# %%
act_2.drop_duplicates(inplace=True)
act_2.reset_index(drop=True, inplace=True)

# %% [markdown]
# valores nulos

# %%
act_2.isna().sum()
# Out:
# YEAR                    0
# AGE                     0
# DISTANCE_BUS            0
# DISTANCE_INTERSTATE     0
# PRICE                  70
# ROOMS                   0
# AREA                    0
# LAND                    0
# BATHS                   0
# dtype: int64

# %%
act_2.dropna()
# Out:
#      YEAR  AGE  DISTANCE_BUS  DISTANCE_INTERSTATE     PRICE  ROOMS  AREA  \
# 0    1978    1       30000.0              30000.0   75900.0      7  1836
# 1    1981    7       22000.0              22000.0  140000.0      6  1800
# 2    1981   31        3000.0               2000.0   68000.0      6  3304
# 4    1981    0       10000.0              13000.0  216000.0      7  2548
# 5    1981    0       25000.0              25000.0  125000.0      7  2208
# ..    ...  ...           ...                  ...       ...    ...   ...
# 326  1981    2       20000.0              20000.0  158000.0      7  2627
# 327  1981   51        2000.0               5000.0   50000.0      5  1140
# 328  1981    1       22000.0              24000.0  162000.0      7  2656
# 329  1978    3       12000.0              12000.0   64900.0      7  2856
# 330  1978   26       20000.0              22000.0   58000.0      6  1356
#
#          LAND  BATHS
# 0     45738.0      2
# 1     44867.0      3
# 2     18731.0      2
# ...

# %%
act_2 = act_2.dropna()

# %%
act_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 262 entries, 0 to 330
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   YEAR                 262 non-null    int64
#  1   AGE                  262 non-null    int64
#  2   DISTANCE_BUS         262 non-null    float64
#  3   DISTANCE_INTERSTATE  262 non-null    float64
#  4   PRICE                262 non-null    float64
#  5   ROOMS                262 non-null    int64
#  6   AREA                 262 non-null    int64
#  7   LAND                 262 non-null    float64
#  8   BATHS                262 non-null    int64
# dtypes: float64(4), int64(5)
# memory usage: 20.5 KB

# %% [markdown]
# # visualización data

# %% [markdown]
# DISPERSION

# %%
sns.scatterplot(data= act_2, y='PRICE', x='AGE', hue='YEAR')
# Out:
# <Axes: xlabel='AGE', ylabel='PRICE'>

# %%
sns.scatterplot(data= act_2, y='PRICE', x='DISTANCE_BUS')
# Out:
# <Axes: xlabel='DISTANCE_BUS', ylabel='PRICE'>

# %%
sns.scatterplot(data= act_2, y='PRICE', x='DISTANCE_INTERSTATE')
# Out:
# <Axes: xlabel='DISTANCE_INTERSTATE', ylabel='PRICE'>

# %% [markdown]
# BOXPLOT

# %%
sns.boxplot(data=act_2, x='YEAR', y='PRICE')
# Out:
# <Axes: xlabel='YEAR', ylabel='PRICE'>

# %%
sns.boxplot(data=act_2, x='ROOMS', y='PRICE')
# Out:
# <Axes: xlabel='ROOMS', ylabel='PRICE'>

# %%
sns.boxplot(data=act_2, x='BATHS', y='PRICE')
# Out:
# <Axes: xlabel='BATHS', ylabel='PRICE'>

# %% [markdown]
# HISTOGRAMA

# %%
sns.histplot(data = act_2, x= 'ROOMS')
# Out:
# <Axes: xlabel='ROOMS', ylabel='Count'>

# %%
sns.histplot(data = act_2, x= 'BATHS')
# Out:
# <Axes: xlabel='BATHS', ylabel='Count'>

# %%
sns.histplot(data = act_2, x= 'LAND')
# Out:
# <Axes: xlabel='LAND', ylabel='Count'>

# %%
sns.histplot(data = act_2, x= 'AREA')
# Out:
# <Axes: xlabel='AREA', ylabel='Count'>

# %%
sns.histplot(data = act_2, x= 'PRICE')
# Out:
# <Axes: xlabel='PRICE', ylabel='Count'>

# %%
sns.histplot(data = act_2, x= 'DISTANCE_BUS')
# Out:
# <Axes: xlabel='DISTANCE_BUS', ylabel='Count'>

# %%
sns.histplot(data = act_2, x= 'DISTANCE_INTERSTATE')
# Out:
# <Axes: xlabel='DISTANCE_INTERSTATE', ylabel='Count'>

# %% [markdown]
# BARRAS

# %%
year = act_2['YEAR'].value_counts()
year.index = ['1978', '1981']

# %%
year
# Out:
# 1978    144
# 1981    118
# Name: YEAR, dtype: int64

# %%
plt.bar(year.index, year.values)
# Out:
# <BarContainer object of 2 artists>
